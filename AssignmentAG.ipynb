# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anthony Gafin**<br>Industrial Chemist and Data Miner

# %% [markdown]
# *I have always been lazy, so if I could make a computer do something for me, I would. This developed into building databases and VBA in spreadsheets to automate<br>mundane tasks. From there I got to experiment with extracting data out of our ERP system - on the quiet, because that <br>was not was I was employed to do, but they loved the results nonetheless.<br><br>After an indusry slow-down I was forced to think of re-skilling, so - here we are, in the Coursera-IBM Assignment!*<br>

# %% [markdown]
# <font color=red>The cell below should raise 2 to the power of 6.</font><br>Why? Becasue we can!

# %%
2^6
# Out:
# [1] 64

# %% [markdown]
# <u><font color=blue>This text is Blue  and Underlined</u></font><br><br>
# - Bullet point 1<br>
#  - Bullet Point 2<br>1. Number list 1<br>2. Number list 2<br>
#  ~~This Text doesn't matter~~,clearly, because it got struck out<br><br>
#
# |Table Heading 1|Table Heading 2|
# |----------------|----------------|
# |A Cell|Antother cell|
# |The last Row|The last cell|
#
# >This is a blocked quote. I haven't found a use for it yet...But what we all want is in the image below!
#
# <img src="https://images.unsplash.com/photo-1516245834210-c4c142787335?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=500&q=60" alt="Got from Open Source Images">
